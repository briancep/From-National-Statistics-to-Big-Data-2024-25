# %% [markdown]
# # Brian Cepparulo - 12/09/2024

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html

# %% [markdown]
# Plot the bar chart

# %%
# %store -r df_hicp_22q4

# %%
plt.figure(figsize=(10, 6))
plt.bar(df_hicp_22q4['geo'], df_hicp_22q4['hex_yoy'])
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
colors=['red' if geo=='EU'
        else
        'blue' for geo in df_hicp_22q4['geo']]
plt.bar(df_hicp_22q4['geo'], df_hicp_22q4['hex_yoy'], color=colors)
plt.ylabel('year over year inflation rate')
plt.title('2022Q2 Core Inflation by country')
plt.xticks(rotation=45)
plt.tight_layout()
